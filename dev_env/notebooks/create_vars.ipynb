# %%
import pandas as pd
from pandas import to_datetime
import numpy as np
import re
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parent   # go up exactly one level
print("PROJECT_ROOT =", PROJECT_ROOT)

# ----------------------------------------------------------------------
# STAGE 1 - Load data and config model
# ----------------------------------------------------------------------

path = PROJECT_ROOT / "output" / "units_mkt_trend_fcst" /  'tvp_kf_coefficients.csv'   
df = pd.read_csv(path)
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df = df.set_index("date")

df
# Out:
# PROJECT_ROOT = C:\Users\Eric\Documents\Python\forecast_system_kf
#                 const  units_mkt_trend_lag1_log  avg_price_trend_log  \
# date
# 2014-01-01   0.037323                  0.793598             0.038957
# 2014-02-01   0.078352                  1.189283            -0.768190
# 2014-03-01   0.102513                  1.029844            -0.794422
# 2014-04-01   0.111528                  0.995354            -1.130339
# 2014-05-01   0.143672                  0.840237            -1.467492
# ...               ...                       ...                  ...
# 2025-05-01  15.161380                  0.136979            -0.714846
# 2025-06-01  15.160394                  0.137581            -0.715183
# 2025-07-01  15.159920                  0.137528            -0.715117
# 2025-08-01  15.131356                  0.137314            -0.712655
# 2025-09-01  15.077880                  0.137543            -0.708368
#
#              rdi_log  home_price_log    covid1    covid2
# date
# ...

# %%
import matplotlib.pyplot as plt

df = df.loc[df.index>"2017-01-01"]
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(df.index, df['avg_price_trend_log'])
ax.set_title("Grocery Market Elasticity")
ax.set_ylabel("Value")
plt.show()
